# %%
import requests
from bs4 import BeautifulSoup

# 取得網頁
response = requests.get('https://www.tenlong.com.tw/products/9787111648178')
soup = BeautifulSoup(response.text, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="zh-Hant-TW">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    Python 程序員面試筆試寶典 | 天瓏網路書店
#   </title>
#   <meta content="authenticity_token" name="csrf-param">
#    <meta content="kGBwVlkJYSEnUAeQoYfIrUnHPnAdx3UVxorwqp20fbbIOrSFAoVw+htoe5hwda+gS9pm66+8Q6ooD+xc/o2jjg==" name="csrf-token">
#     <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
#     <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#     <link href="/favicon.ico" rel="shortcut icon"/>
#     <link href="/images/logo-simple.png" rel="apple-touch-icon"/>
#     <link href="/manifest.json" rel="manifest"/>
#     <link href="https://fonts.googleapis.com/css?family=Noto+Sans+TC&amp;display=swap" rel="stylesheet"/>
# ...

# %%
from bs4 import BeautifulSoup, NavigableString, Tag

# Python程序員面試筆試寶典
table_contents = soup.find_all("div", class_="item-desc")[2]
ch2 = table_contents.findAll('p')[1]
ch2_qlist = ch2.getText().split('\r\n')
ch2_qlist = list(map(lambda x: x.split(' ')[1], ch2_qlist))
ch2_qlist
q_dict = {ch2_qlist[0]:ch2_qlist[1:-3]}
q_dict
# Out:
# {'Python基礎5': ['什麼是Python？使用Python有什麼好處？',
#   'Python中常用的保留字有哪些？',
#   'Python',
#   'Python中有哪些常見的運算符？',
#   '運算符is與=',
#   '數據類型14',
#   'Python都有哪些自帶的數據類型？可變類型和不可變類型分別包括哪些？',
#   '列表、元組、集合、字典的區別有哪些？',
#   '列表和元組的區別有哪些？',
#   'Python有哪些常見的數據類型轉換函數？',
#   '列表、元組、集合及字典之間如何相互轉換？',
#   '如何刪除一個列表（list）中的重複元素？',
#   '如何求兩個列表（list）的交集、差集或併集？',
#   '如何反序地迭代一個序列？',
#   '列表的sort方法和sorted方法有何區別？',
#   '列表中常用的方法有哪些？',
#   '什麼是列表生成式？',
#   '字符串格式化%和.format的區別是什麼？',
#   '單引號、雙引號和三引號的區別有哪些？',
#   'Python中常用字符串函數有哪些？',
#   '如何判斷一個字符串是否全為數字？',
#   'Python字典有哪些內置函數？',
#   '字典的items()方法與iteritems()方法有什麼不同？',
#   '集合常見內置方法有哪些？',
#   '其他37',
#   'Python中的日期和時間49',
#   '編寫函數返回昨天的日期52',
#   '計算每個月的天數52',
#   '如何獲取某月的日曆？',
#   '流程控制語句53',
#   'Python中pass語句的作用是什麼？',
#   '用程序實現斐波納契數列53',
#   'Python編程中的except有哪些作用？',
#   '給出一個自定義異常的示例55',
#   'range()函數的作用有哪些？',
#   'xrange和range的區別有哪些？',
#   '生成九九乘法表58',
#   '打印三角形59',
#   '簡單計算器60',
#   '1,2,3,4,5能組成多少個互不相同的無重複的三位數？請用程序分別列出61',
#   '判斷用戶輸入的年份是否為閏年62',
# ...
